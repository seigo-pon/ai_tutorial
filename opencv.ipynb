# %%
# !wget http://optipng.sourceforge.net/pngtech/img/lena.png
# Out:
# --2020-05-09 23:47:53--  http://optipng.sourceforge.net/pngtech/img/lena.png
# optipng.sourceforge.net (optipng.sourceforge.net) をDNSに問いあわせています... 216.105.38.10
# optipng.sourceforge.net (optipng.sourceforge.net)|216.105.38.10|:80 に接続しています...接続しました。
# HTTP による接続要求を送信しました、応答を待っています...200 OK
# 長さ: 473831 (463K) [image/png]
# `lena.png' に保存中
#
# lena.png            100%[===================>] 462.73K   473KB/s 時間 1.0s
#
# 2020-05-09 23:47:54 (473 KB/s) - `lena.png' へ保存完了 [473831/473831]

# %%
import cv2

img = cv2.imread('lena.png')
print(img)
# Out:
# [[[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  ...
#
#  [[ 60  18  84]
#   [ 60  18  84]
#   [ 58  27  92]
#   ...
#   [ 84  73 173]
#   [ 76  68 172]
#   [ 79  62 177]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cv2.imwrite('copy.jpg', img)
# Out:
# True

# %%
img2 = cv2.resize(img, (600, 300))
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img3 = img[200:400, 200:400]
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_alt.xml
# Out:
# --2020-05-09 23:58:23--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_alt.xml
# raw.githubusercontent.com (raw.githubusercontent.com) をDNSに問いあわせています...151.101.88.133
# raw.githubusercontent.com (raw.githubusercontent.com)|151.101.88.133|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています...200 OK
# 長さ: 676709 (661K) [text/plain]
# `haarcascade_frontalface_alt.xml' に保存中
#
# haarcascade_frontal 100%[===================>] 660.85K  --.-KB/s 時間 0.06s
#
# 2020-05-09 23:58:23 (11.6 MB/s) - `haarcascade_frontalface_alt.xml' へ保存完了 [676709/676709]

# %%
cascade_file = './haarcascade_frontalface_alt.xml'
cascade = cv2.CascadeClassifier(cascade_file)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

face_list = cascade.detectMultiScale(gray, minSize=(150, 150))
for (x, y, w, h) in face_list:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), thickness=20)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
